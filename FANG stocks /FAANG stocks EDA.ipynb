# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('faang_stocks_pandemic_data.csv')
df.head(3)
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.drop(labels='Unnamed: 0',axis=1,inplace=True)
df.head(3)
# Out:
#         Date        High         Low        Open       Close      Volume  \
# 0 2020-01-02  209.789993  206.270004  206.750000  209.779999  12077100.0
# 1 2020-01-03  210.399994  206.949997  207.210007  208.669998  11188400.0
# 2 2020-01-06  212.779999  206.520004  206.699997  212.600006  17058900.0
#
#     Adj Close      Name
# 0  209.779999  Facebook
# 1  208.669998  Facebook
# 2  212.600006  Facebook

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2840 entries, 2020-01-02 to 2022-04-01
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       2840 non-null   float64
#  1   Low        2840 non-null   float64
#  2   Open       2840 non-null   float64
#  3   Close      2840 non-null   float64
#  4   Volume     2840 non-null   float64
#  5   Adj Close  2840 non-null   float64
#  6   Name       2840 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 177.5+ KB

# %%
df.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close', 'Name'], dtype='object')

# %%
df.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  2840.000000  2840.000000  2840.000000  2840.000000  2.840000e+03
# mean   1209.156423  1180.196246  1195.034564  1194.873321  3.099634e+07
# std    1212.303369  1185.486963  1199.645063  1198.823284  5.338770e+07
# min      57.125000    53.152500    57.020000    56.092499  4.656000e+05
# 25%     232.245003   224.582500   228.807503   229.680000  2.771200e+06
# 50%     508.634995   495.050003   502.580002   502.234985  5.637150e+06
# 75%    2376.017517  2322.380005  2361.729980  2352.322449  2.657248e+07
# max    3773.080078  3696.790039  3744.000000  3731.409912  4.265100e+08
#
#          Adj Close
# count  2840.000000
# mean   1194.732621
# std    1198.950567
# min      55.332169
# 25%     229.680000
# 50%     502.234985
# 75%    2352.322449
# max    3731.409912

# %%
import pandas_profiling as pp

# %%
pp.ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.2.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-05-25 17:59:19.575678&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df.Name.value_counts()
# Out:
# Facebook    568
# Amazon      568
# Apple       568
# Netflix     568
# Google      568
# Name: Name, dtype: int64

# %%
#Filter data for Amazon
df[df['Name']=='Amazon']
# Out:
#                    High          Low         Open        Close     Volume  \
# Date
# 2020-01-02  1898.010010  1864.150024  1875.000000  1898.010010  4029000.0
# 2020-01-03  1886.199951  1864.500000  1864.500000  1874.969971  3764400.0
# 2020-01-06  1903.689941  1860.000000  1860.000000  1902.880005  4061800.0
# 2020-01-07  1913.890015  1892.040039  1904.500000  1906.859985  4044900.0
# 2020-01-08  1911.000000  1886.439941  1898.040039  1891.969971  3508000.0
# ...                 ...          ...          ...          ...        ...
# 2022-03-28  3380.750000  3298.000000  3299.500000  3379.810059  2992700.0
# 2022-03-29  3416.629883  3357.370117  3407.679932  3386.300049  3307700.0
# 2022-03-30  3379.010010  3310.000000  3370.189941  3326.020020  2808400.0
# 2022-03-31  3329.899902  3259.070068  3328.899902  3259.949951  2998300.0
# 2022-04-01  3316.540039  3246.389893  3282.989990  3271.199951  2851800.0
#
#               Adj Close    Name
# Date
# 2020-01-02  1898.010010  Amazon
# ...

# %% [markdown]
# ## Distribution plot

# %%
sns.distplot(df['Low'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Low', ylabel='Density'>

# %%
sns.histplot(df['High'])
# Out:
# <AxesSubplot:xlabel='High', ylabel='Count'>

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(df['Close'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Close'>

# %%
sns.boxenplot(df['Open'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Open'>

# %% [markdown]
# # Bi-Variate Charts

# %% [markdown]
# ## Line Charts

# %%
#plt.figure(12,8)
plt.xticks(rotation=45)
sns.lineplot(data=df,x='Date',y='Close',hue='Name')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %% [markdown]
# ## Barplot

# %%
sns.barplot(data=df,x='Name',y='Volume')
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Volume'>

# %% [markdown]
# ## Heatmap

# %%
data_corr = df.corr()
sns.heatmap(data_corr,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Scatterplot

# %%
sns.scatterplot(x=df.Low,y=df.High)
# Out:
# <AxesSubplot:xlabel='Low', ylabel='High'>

# %%
# Boxplot

sns.boxplot(data=df,x='Name',y='Volume')
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Volume'>

# %%
## Which company is generating max revenue in stock
